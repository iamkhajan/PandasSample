# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt


def draw_graph():
    bar1 = pd.crosstab(df.DeviceModel,df.Rating).plot(kind='bar')
    bar2 = pd.crosstab(df.Rating,df.Rating).plot(kind='bar')
    plt.savefig("test.pdf")
    

def plot_bar_device_model(x_axis_data,y_axis_data):
    # this is for plotting purpose
    index = np.arange(len(x_axis_data))
    plt.bar(index, y_axis_data)
    plt.xlabel('Genre', fontsize=5)
    plt.ylabel('No of Movies', fontsize=5)
    plt.xticks(index, x_axis_data, fontsize=5, rotation=30)
    plt.title('Feedback graph')
    plt.show()
    
    
#load file
df = pd.read_csv("FeedBackReportForSeptember2018.csv")
#drop na
df.dropna()
#putting to uppercase
df.Rating = df.Rating.str.upper()
draw_graph()
# new_df=pd.DataFrame(pd.crosstab(df.DeviceModel,df.Rating))
# new_df
# plot_bar_device_model(df.DeviceModel,df.Rating)
# plot_bar_device_model(df.Rating,df.Rating)
